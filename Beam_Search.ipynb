# %% [markdown]
# ## Function: `one_point_simulation`
#
# Simulates the logical error rate of a specific quantum code under a given noise rate, a specified circuit and decoder.
#
# ```python
# def one_point_simulation(
#     n: int,
#     k: int,
#     p_CNOT: float,
#     circuit_type: str,
#     decoder: str,
#     maximum_shots: int = 100_000,
#     maximum_errors: int = 100,
# )
# ```
#
# ### Allowed Parameter Configurations
#
# The input parameters `(n, k, p_CNOT, circuit_type)` must be selected from the following pre-defined sets:
# ```
# 144, 12, 0.001, "normal"
# 144, 12, 0.002, "normal"
# 144, 12, 0.003, "normal"
# 144, 12, 0.004, "normal"
# 144, 12, 0.005, "normal"
# 144, 12, 0.006, "normal"
#
# 90, 8, 0.002, "normal"
# 90, 8, 0.003, "normal"
# 90, 8, 0.004, "normal"
# 90, 8, 0.005, "normal"
# 90, 8, 0.002, "XYZ"
# 90, 8, 0.003, "XYZ"
# 90, 8, 0.004, "XYZ"
# 90, 8, 0.005, "XYZ"
#
# 450, 32, 0.002, "normal"
# 450, 32, 0.003, "normal"
# 450, 32, 0.004, "normal"
# 450, 32, 0.005, "normal"
# ```
# ### Supported Decoders
# The `decoder` argument accepts the following values:
# * 'bp30+osd'
#
# * 'beam8_230iters'
#
# * 'beam32_340iters'
#
# * 'beam64_640iters'
#
# * 'beam64_32res_640iters'

# %%
from simulation_functions import one_point_simulation

one_point_simulation(n=144, k=12, p_CNOT=0.003, circuit_type='normal', decoder='beam8_230iters', maximum_shots=100000, maximum_errors=200)
# Out:
# Starting 11 workers...
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99999         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99991         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99950         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99869         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99821         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99789         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99725         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99629         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99597         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99565         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99501         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99405         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99373         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99181         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99117         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99085         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99021         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98989         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98893         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98829         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98797         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98669         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98573         200 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98541         199 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98445         199 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98413         199 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98381         199 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98221         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98125         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98077         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97981         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97885         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97853         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97757         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97693         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97597         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97501         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97437         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97405         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97277         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97149         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97117         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97053         197 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96829         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96797         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96733         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96637         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96573         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96477         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96445         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96381         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96349         196 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96253         195 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96189         195 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95933         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95917         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95821         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95789         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95693         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95565         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95437         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95341         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95245         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95181         193 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95053         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94797         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94701         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94637         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94541         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94477         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94253         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94125         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94029         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93901         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93837         192 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93613         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93517         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93421         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93325         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93197         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93069         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92973         190 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92717         189 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92365         189 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92269         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92205         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      92077         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91917         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91789         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91661         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91565         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91469         188 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91309         187 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91181         186 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      91053         185 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      90701         185 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      90509         185 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      90189         185 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      89965         184 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      89741         184 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      89549         184 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      89325         184 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      89165         183 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      88845         181 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      88685         179 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      88429         179 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      88173         179 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      87917         179 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      87725         178 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      87533         177 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      87341         177 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      87117         175 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      86765         174 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      86477         173 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      86141         173 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      85757         173 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      85437         172 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      85085         172 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      84733         171 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      84413         171 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      84061         170 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      83741         170 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      83357         167 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82909         167 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82525         166 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82045         165 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      81725         162 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      81373         159 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      80925         159 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      80541         159 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      80125         158 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      79709         156 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      79261         155 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      78781         153 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      78237         151 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      77677         149 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      77037         146 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      76429         146 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      75853         145 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      75245         144 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      74733         141 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      74189         140 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      73613         138 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      72941         138 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      72237         136 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      71373         133 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      70637         129 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      69837         127 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      68941         126 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      68077         125 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      67325         120 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      66557         118 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      65757         116 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      64797         115 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      63933         114 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      62653         114 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      61373         113 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      60093         112 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      58973         109 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      57885         108 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      56669         106 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      55597         103 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      54445         100 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      53229         100 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      52173          96 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      50957          95 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      49581          90 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      48077          88 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      46765          82 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      44973          81 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      43277          78 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      41517          76 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      40013          75 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      36749          68 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      35213          65 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      33709          61 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      31661          52 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      29357          49 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      26829          47 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      24621          43 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      22589          38 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      15853          28 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      13613          26 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      11517          21 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       9373          20 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8923          19 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8233          17 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8217          17 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8179          17 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       7432          16 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       6696          16 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       6685          16 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       6009          15 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       5369          13 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       4548          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       3940          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       3128          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       3056          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2922          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2861          12 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2189          11 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2185          11 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1577           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1314           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1036           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        949           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        890           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        785           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        778           9 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        634           8 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        495           8 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        210           7 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        180           7 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m         90           7 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m         45           7 p_CNOT=0.003,x_or_z=x
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters   ?          0           7 p_CNOT=0.003,x_or_z=x
# Starting 11 workers...
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99999         200 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  3m      99992         200 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      99910         200 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99813         200 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      99781         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      99717         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      99621         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99557         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99397         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99365         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99269         199 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99205         198 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99173         198 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99109         198 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      99077         198 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      98949         197 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98789         197 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98661         197 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98597         197 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98565         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98501         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98405         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98341         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98245         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98053         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      98021         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97925         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97861         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97733         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97701         196 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97573         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97541         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97413         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97381         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97317         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97253         195 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97093         194 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      97061         194 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96869         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96837         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96773         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96741         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96645         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96581         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96485         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96389         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96325         193 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96133         191 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96069         191 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      96037         191 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95973         191 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95797         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95733         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95701         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95589         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95541         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95477         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95285         190 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95189         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      95157         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94997         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94933         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94805         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94741         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94645         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94581         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94549         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94421         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94357         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94293         189 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94165         188 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      94101         188 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93909         187 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93749         186 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93525         186 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93461         186 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93397         186 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93333         185 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93269         185 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      93173         185 p_CNOT=0.003,x_or_z=z
# ...
#        11 beam8_230iters  2m      83493         168 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      83173         168 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82917         168 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82693         168 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82373         168 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      82021         164 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      81541         164 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      81157         164 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      80709         164 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      80325         163 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      79941         161 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      79493         161 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      79045         160 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      78597         159 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      78149         159 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      77765         158 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      77397         156 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      76789         156 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      76245         155 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      75829         151 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      75157         151 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      74645         149 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      74069         149 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      73493         148 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      72853         147 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      72245         146 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      71733         145 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      70869         145 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      70101         143 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      69237         142 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      68373         141 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      67605         139 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      66805         137 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  2m      65941         136 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      65013         135 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      64245         133 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      63493         130 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      62629         128 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      61573         125 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      60325         122 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      59269         121 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      58117         120 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      57189         115 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      56005         114 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      54789         112 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      53541         109 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      52325         106 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      51045         104 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      49797         104 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      48133         102 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      46469         100 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters  1m      44901          97 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      43381          94 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      41813          93 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      40117          91 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      38677          87 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      37157          84 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      35653          79 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      33989          76 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      32485          72 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      30245          67 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      28229          63 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      25957          60 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      23749          57 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      21669          54 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      19621          49 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      17253          46 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      15141          42 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      12965          39 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m      10933          34 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8917          30 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       8451          29 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       7937          28 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       7169          28 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       6399          27 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       4894          24 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       4350          21 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       4330          21 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       3754          17 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2794          16 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2212          16 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2142          16 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2102          16 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       2059          16 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1611          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1592          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1585          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1528          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1526          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1334          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1331          15 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m       1138          14 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        736          12 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        730          12 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m        591          12 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters <1m         62          10 p_CNOT=0.003,x_or_z=z
# 1 tasks left:
#   workers        decoder eta shots_left errors_left json_metadata
#        11 beam8_230iters   ?          0          10 p_CNOT=0.003,x_or_z=z
# beam8_230iters normal circuit memory_X results:
# num errors is 193, num shots is 100000, X logical error rate is 0.00016083333333333333
# beam8_230iters normal circuit memory_Z results:
# num errors is 190, num shots is 100000, Z logical error rate is 0.00015833333333333332
# Total (X+Z) logical error rate is 0.00031916666666666665

# %% [markdown]
# # Function: `decoding_time`
#
# Simulates the runtime of different decoders decoding the [[144,12,12]] BB code with 12 syndrome extraction rounds
#
# ```python
# def decoding_time(p_CNOT: float, decoder: str, num_shots: int = 10_000)
# ```
#
# `p_CNOT` allowed values: `0.0005`, `0.001`
#
# `decoder` allowed values: 'bp30+osd', 'beam8_230iters', 'beam32_340iters', 'beam64_640iters'
#
# For every p_CNOT and decoder, this function outputs the average decoding time and 99.9 percentile decoding time

# %%
from simulation_functions import decoding_time

decoding_time(p_CNOT=0.0005, decoder="beam8_230iters", num_shots=10000)
# Out:
# beam8_230iters decodes [[144,12,12]] BB code with 12 syndrome extraction rounds at noise rate 0.0005:
# The average decoding time is 0.0016494821908185258, and the 99.9 percentile decoding time is 0.008600207976996899

# %% [markdown]
# # Function: `full_simulation`
#
# Runs full simulation for the specified code
#
# ```python
# def full_simulation(n: int, k: int, maximum_shots: int = 1_000_000, maximum_errors: int = 100)
# ```
#
# It supports three code instances: [[144, 12, 12]] BB code, [[90, 8, 10]] BB code, and [[450, 32, 8]] HGP code, meaning that the inputs (n, k) must be selected from the following three pairs: (144, 12), (90, 8), and (450, 32)
#
# The simulation results will be stored in a csv file in the `simulation_results` folder

# %%
from simulation_functions import full_simulation

full_simulation(n=90, k=8, maximum_shots=100, maximum_errors=100)
# Out:
# Starting 11 workers...
# 24 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 24 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 24 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 23 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters <1m         99          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 22 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters <1m         99          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 22 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters <1m         65          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         67         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 22 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1 beam64_640iters <1m         19         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1  beam8_230iters <1m         65          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         67         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1  beam8_230iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 18 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         67         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         67         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 18 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 18 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.002,x_or_z=z
#         1        bp30+osd <1m         83         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         95         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         95         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         91         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         95         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         91         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         91         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         95         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         91         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         95         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 16 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         19          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 15 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         19          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         51         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=z
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 14 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1        bp30+osd <1m         19          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         65          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         91          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         0        bp30+osd ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 13 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         65          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1        bp30+osd <1m         87         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1  beam8_230iters <1m         59         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1 beam64_640iters <1m         99         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=z
#         1        bp30+osd <1m         91          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1  beam8_230iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1 beam64_640iters   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=x
#         1        bp30+osd   ?        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0  beam8_230iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
#         0 beam64_640iters ?·∞        100         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=z
# 13 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         1 beam64_640iters <1m         35         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.003,x_or_z=x
#         1        bp30+osd <1m         79         100 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
#         1  beam8_230iters <1m         65          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.004,x_or_z=x
# ...
#         5 beam64_640iters  1m         14          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         38          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters  1m         12          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         38          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters  1m         11          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         37          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters  1m         11          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         37          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          9          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         36          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          9          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         35          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          9          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         34          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          9          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         34          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          8          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         33          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          8          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         33          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          7          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         33          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          6          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         33          97 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          5          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         32          96 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          5          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         31          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          5          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         30          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          5          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  5m         30          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          4          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         29          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          4          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         28          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          4          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         27          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          4          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         26          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          4          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         26          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          3          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         26          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          2          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         25          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          2          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         25          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          1          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 2 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#         6 beam64_640iters  4m         24          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
#         5 beam64_640iters <1m          1          99 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_z
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  2m         24          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  2m         23          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  2m         22          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  2m         21          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  2m         19          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         18          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         17          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         16          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         15          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         14          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters  1m         13          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m         12          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m         11          95 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m         10          94 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          9          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          8          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          7          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          6          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          5          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          4          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          3          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          2          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 1 tasks left:
#   workers         decoder eta shots_left errors_left json_metadata
#        11 beam64_640iters <1m          1          93 code=[[90, 8, 10]] BB code,syndrome_rounds=10,p_CNOT=0.005,x_or_z=xyz_x
# 0 tasks left:

# %% [markdown]
# # Function: `plot_logical_error_rate`
#
# Plots the logical error rate for the specified code.
#
# ```python
# def plot_logical_error_rate(n: int, k: int)
# ```
#
# The inputs (n, k) must be selected from the following three pairs: (144, 12), (90, 8), and (450, 32).
#
# ⚠️ **Prerequisite:** `plot_logical_error_rate(n, k)` depends on the CSV output from `full_simulation(n, k)`. Please ensure the simulation has completed before attempting to plot.

# %%
from simulation_functions import plot_logical_error_rate

plot_logical_error_rate(90, 8)
